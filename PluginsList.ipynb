# %%
""""
# !pip install zipfile36
# !pip install requests
# !pip install wget
"""
import requests
import pandas as pd
import xml.etree.ElementTree as ET
import zipfile as zp
import os
import wget
import re

class PluginReader:
    
    temp = os.path.join(os.curdir,'temp') 
    
    def __init__(self, url):
        self.url = url
    
    def createTempDir():
        try:
            os.mkdir(os.path.join(os.curdir,'temp'))
        except FileExistsError:
            print("Le dossier temp est déjà créé")


    def dropTempDir(self):
        try:
            os.remove(os.path.join(self.temp,'content.xml'))
            os.remove(os.path.join(self.temp,'content.jar'))
            os.remove(self.temp)
        except PermissionError:
            print('Droit de suppression absent')
        except FileNotFoundError:
            print('Fichier absent')

    def getxml(self):
        return  ET.XML(requests.get(self.url).text)

    def getXMLData(self):
        path = wget.download(self.url,self.temp)
        os.rename(zp.ZipFile(path).extract('content.xml'),os.path.join(self.temp,'content.xml'))
        data = ET.parse(os.path.join(self.temp,'content.xml'))
        return data

    def getData(self):
        jar = re.compile('\.jar$', re.IGNORECASE)
        xml = re.compile('\.xml$', re.IGNORECASE)
        if len(re.findall(jar,self.url)) > 0:
            if re.findall(jar,self.url)[0] == '.jar':
                root = self.getXMLData().getroot()
        elif len(re.findall(xml,self.url)):
            if re.findall(xml,self.url)[0] == '.xml':
                root = getxml()
        return root



    def listPlugins(self):
        self.dropTempDir()
        root = self.getXMLData().getroot()
        plugins = {}
        for child in root:
            for schild in child:
                if schild.tag == 'unit':
                    for xchild in schild:
                        if xchild.tag == 'provides':
                            dico = {}
                            versionList = []
                            for provided in xchild:
                                versionList.append(provided.attrib['version'])
                            plugins[schild.attrib['id']] = sorted(set(versionList),reverse=True) 
        self.dropTempDir()
        return plugins
    
    def getPlugin(self,id):
        return self.listPlugins()[id]
            
url1 = 'https://download.jboss.org/jbosstools/updates/m2e-extensions/m2e-jdt-compiler/1.0.0/content.jar'
url2 =  'http://dependencies.sarl.io/content.jar' 
url3 = 'http://download.eclipse.org/releases/2019-12/201910181000/content.jar'
url4 = 'http://download.tuxfamily.org/arakhne/p2/content.jar'

# %%
p = PluginReader(url3)
plug = p.listPlugins()
# Out:
# Fichier absent
# 100% [......................................................] 3184832 / 3184832Droit de suppression absent

# %%
plug
# Out:
# {'org.eclipse.pde.ds.annotations.source': ['1.1.600.v20190929-1236', '1.0.0'],
#  'org.eclipse.viatra.transformation.evm.transactions': ['2.3.0.201910160845',
#   '1.0.0',
#   '0.0.0'],
#  'org.apache.batik.util': ['1.11.0.v20190515-0436', '1.11.0', '1.0.0'],
#  'org.eclipse.tips.feature.feature.group': ['1.0.0', '0.2.700.v20190918-0517'],
#  'org.eclipse.wb.swing.FormLayout': ['1.9.1.201812270937', '1.0.0', '0.0.0'],
#  'org.eclipse.rse.subsystems.processes.core': ['4.5.100.201901312252',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.viatra.addon.viewers.runtime.feature.source.feature.group': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.tracecompass.gdbtrace.feature.group': ['5.1.0.201909110900',
#   '1.0.0'],
#  'org.eclipse.m2e.wtp.jsf.feature.source.feature.jar': ['1.4.2.20190530-0057',
#   '1.0.0'],
#  'org.eclipse.datatools.connectivity.oda.feature.feature.group': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.jst.ws.jaxws.dom.feature.feature.group': ['1.0.302.v201903021515',
#   '1.0.0'],
#  'org.eclipse.linuxtools.docker.editor.source': ['1.0.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.ecf.eventadmin.feature.feature.jar': ['2.0.100.v20181107-1749',
#   '1.0.0'],
#  'org.eclipse.birt.report.engine.emitter.html.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.ecf.provider.xmpp': ['3.2.300.v20180227-0153',
#   '3.2.0',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.gef.dot.source.feature.group': ['5.0.400.201910161621', '1.0.0'],
#  'org.eclipse.emf.ecp.view.validation': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.emf.mwe.utils': ['1.5.1.M1', '1.0.0', '0.0.0'],
#  'org.eclipse.jst.jsp.ui': ['1.2.200.v201904272124', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.cdo.server.mongodb.feature.jar': ['5.0.0.v20180529-1130',
#   '1.0.0'],
#  'org.eclipse.emf.cdo': ['4.6.100.v20180529-1130', '4.6.100', '1.0.0'],
#  'org.eclipse.net4j.db.doc.feature.jar': ['4.2.500.v20180530-1201', '1.0.0'],
#  'org.eclipse.emf.cdo.security.editor': ['4.2.500.v20180529-1130',
#   '4.2.100',
#   '1.0.0'],
#  'org.eclipse.papyrus.infra.core.sasheditor': ['2.2.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.swtbot.go': ['2.8.0.201906121535', '1.0.0'],
#  'org.eclipse.wst.xml_ui.feature.feature.jar': ['3.15.0.v201907091226',
#   '1.0.0'],
#  'org.eclipse.emf.cdo.common.source': ['4.7.0.v20180529-1130', '1.0.0'],
#  'org.eclipse.bpel.feature.feature.jar': ['1.1.2.Final-v20180621-1835',
#   '1.0.0'],
#  'org.eclipse.datatools.enablement.sap.maxdb.ui': ['1.2.101.201811012051',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.wst.server_adapters.feature.feature.group': ['3.2.700.v201901310132',
#   '1.0.0'],
#  'org.eclipse.jface.text': ['3.16.100.v20190926-0902', '1.0.0', '0.0.0'],
#  'org.eclipse.ptp.pldt.upc.feature.jar': ['9.3.1.201909101427', '1.0.0'],
#  'org.eclipse.oomph.setup.targlets.feature.group': ['1.12.0.v20190920-0437',
#   '1.0.0'],
#  'org.eclipse.e4.tools': ['4.8.600.v20191001-0938',
#   '1.0.0',
#   '0.12.0.qualifier'],
#  'org.eclipse.cdt.autotools.feature.jar': ['9.9.0.201909091953', '1.0.0'],
#  'org.eclipse.remote.telnet.core': ['1.0.0.201909031456', '1.0.0', '0.0.0'],
#  'org.eclipse.ecf.filetransfer.httpclient45.feature.feature.jar': ['1.0.0.v20190530-1947',
#   '1.0.0'],
#  'org.eclipse.swt': ['3.112.100.v20191008-0601', '1.0.0', '0.0.0'],
#  'org.eclipse.net4j.doc.feature.group': ['4.2.500.v20180530-1201', '1.0.0'],
#  'org.eclipse.oomph.version.feature.jar': ['1.12.0.v20190823-0737', '1.0.0'],
#  'org.eclipse.emf.eef.views.source': ['1.5.1.201601141612', '1.0.0'],
#  'org.eclipse.emf.ecp.view.compoundcontrol.swt': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.gef.fx.sdk.feature.jar': ['5.0.3.201910161621', '1.0.0'],
#  'org.eclipse.egf.producer.fprod': ['1.6.1.201910041425', '1.0.0', '0.0.0'],
#  'org.eclipse.rcptt.platform.feature.group': ['2.4.2.201905080445', '1.0.0'],
#  'org.eclipse.birt.report.engine.emitter.wpml': ['4.7.0.v201706222054',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.ecp.cdo.ui': ['1.23.0.20191007-1207', '1.23.0', '1.0.0'],
#  'org.eclipse.linuxtools.jdt.docker.launcher.source': ['1.0.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.gef.cloudio.user.feature.group': ['5.0.2.201910161621', '1.0.0'],
#  'org.eclipse.tm.terminal.control.feature.feature.jar': ['4.5.102.201907301734',
#   '1.0.0'],
#  'org.eclipse.gmf.runtime.emf.core.source': ['1.7.0.201905141505', '1.0.0'],
#  'org.eclipse.jst.server.ui.doc.user': ['1.0.600.v201901310132', '1.0.0'],
#  'org.eclipse.emf.codegen.ecore.ui.source': ['2.20.0.v20190919-0941', '1.0.0'],
#  'org.eclipse.equinox.p2.sdk.feature.group': ['3.11.600.v20191008-0645',
#   '1.0.0'],
#  'org.eclipse.papyrus.uml.decoratormodel': ['2.3.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.m2e.wtp.jaxrs.feature.feature.jar': ['1.4.2.20190530-0057',
#   '1.0.0'],
#  'org.eclipse.lsp4j.debug': ['1.0.0', '0.8.0.v20190822-0801'],
#  'org.eclipse.emf.diffmerge.sirius.feature.feature.group': ['1.0.0',
#   '0.11.2.201906100817'],
#  'org.eclipse.ocl.uml.source.feature.group': ['5.10.1.v20191014-1354',
#   '1.0.0'],
#  'org.eclipse.rcptt.ui.activities': ['2.4.2.201903220647', '1.0.0'],
#  'org.eclipse.papyrus.uml.diagram.composite': ['3.2.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jwt.transformations.bpmn': ['1.6.0.201605250940',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.ecp.view.table.feature.source.feature.jar': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'com.mycorp.examples.timeservice.consumer': ['1.1.100.v20180702-0050',
#   '1.0.0'],
#  'org.eclipse.emf.oda.ecore.ui.feature.group': ['1.6.0.v20190323-1059',
#   '1.0.0'],
#  'org.eclipse.wst.server_core.feature.feature.jar': ['3.3.700.v201903232121',
#   '1.0.0'],
#  'org.eclipse.jgit.pgm.feature.group': ['5.5.0.201909110433-r', '1.0.0'],
#  'org.eclipse.wb.doc.user': ['1.9.1.201812270937', '1.0.0'],
#  'org.eclipse.userstorage.source': ['1.2.0.v20190307-0457', '1.0.0'],
#  'org.eclipse.dltk.debug.ui': ['6.0.0.201909210130', '1.0.0', '0.0.0'],
#  'org.eclipse.birt.core.source': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.tcf.te.tcf.ui': ['1.6.1.201907191905', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.ecp.emf2web': ['1.23.0.20191007-1207', '1.23.0', '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.tools.coverage.junit.source.feature.jar': ['1.6.1.v20191014-1442',
#   '1.0.0'],
#  'org.eclipse.acceleo.traceability.model.source': ['3.7.8.201902261618',
#   '1.0.0'],
#  'org.eclipse.birt.report.engine.emitter.config.html.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.datatools.enablement.msft.feature.feature.group': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.passage.lic.licenses.e4.ui': ['1.0.0', '0.5.0.v20190904-1720'],
#  'org.eclipse.papyrus.infra.services.viewersearch': ['3.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.mwe.ui.feature.feature.group': ['1.5.1.M1', '1.0.0'],
#  'org.eclipse.ocl.examples.impactanalyzer.util': ['3.10.400.v20191014-1354',
#   '1.0.0',
#   '0.0.0'],
#  'org.json': ['1.0.0.v201011060100', '1.0.0', '0.0.0'],
#  'org.eclipse.sirius.properties.defaultrules': ['6.2.3.201908120659',
#   '5.0.0',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.view.rule.model.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.pushingpixels.trident': ['1.2.0.v201305152020', '1.0.0', '0.0.0'],
#  'org.eclipse.datatools.oda.cshelp': ['1.3.101.201811012051', '1.0.0'],
#  'org.w3c.css.sac': ['1.3.1.v200903091627', '1.3.0', '1.0.0'],
#  'org.eclipse.papyrus.uml.expressions': ['2.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.ui.themes': ['1.2.800.v20191002-1342', '1.0.0'],
#  'org.eclipse.cdt.debug.gdbjtag': ['7.0.1.201811241055', '1.0.0'],
#  'org.eclipse.cdt.cmake.feature.group': ['9.9.0.201908222044', '1.0.0'],
#  'org.eclipse.oomph.setup.git.edit': ['1.5.0',
#   '1.10.0.v20180706-1242',
#   '1.0.0'],
#  'org.eclipse.ocl.examples.interpreter.source': ['4.9.0.v20191014-1354',
#   '1.0.0'],
#  'com.mycorp.examples.timeservice.consumer.filediscovery.rest': ['1.2.100.v20190515-1132',
#   '1.0.0'],
#  'org.eclipse.equinox.server.jetty.feature.group': ['1.10.100.v20191004-1029',
#   '1.0.0'],
#  'org.eclipse.acceleo.profiler.editor': ['3.7.8.201902261618',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.gef.layout.source.feature.group': ['5.0.0.201910161621',
#   '1.0.0'],
#  'org.eclipse.birt.data.oda.mongodb.source': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.emf.ecp.ui.rcp.source': ['1.23.0.20191007-1207', '1.0.0'],
#  'org.eclipse.emf.ecore.xcore.ui': ['1.12.0.v20190924-0817', '1.0.0', '0.0.0'],
#  'org.eclipse.ecf.sync': ['2.0.200.v20180302-2006', '2.0.0', '1.0.0'],
#  'org.eclipse.emf.mapping.ecore.editor.source': ['2.8.0.v20180706-1146',
#   '1.0.0'],
#  'org.eclipse.linuxtools.valgrind.helgrind': ['1.1.0.201910151606', '1.0.0'],
#  'org.eclipse.jst.jsf.ui': ['1.6.102.v201902121810', '1.0.0', '0.0.0'],
#  'org.eclipse.jgit.http.apache.feature.jar': ['5.5.0.201909110433-r', '1.0.0'],
#  'org.eclipse.wst.sse.ui': ['1.6.0.v201905291408', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.edit.ui.source.feature.group': ['2.18.0.v20190920-0412',
#   '1.0.0'],
#  'org.eclipse.linuxtools.rpmstubby': ['1.2.0.201910151606', '1.0.0', '0.0.0'],
#  'org.eclipse.ui.workbench.texteditor': ['3.14.0.v20191004-1446',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.xtext.xbase.ide': ['2.20.0.v20191014-0549', '1.0.0', '0.0.0'],
#  'org.eclipse.viatra.query.tooling.ui.retevis': ['1.0.0',
#   '0.23.0.201910160845',
#   '0.0.0'],
#  'org.eclipse.gef.geometry.sdk.feature.group': ['5.0.2.201910161621', '1.0.0'],
#  'toolingorg.eclipse.platform.sdk.config.cocoa.macosx.x86_64': ['4.14.0.I20191009-1800'],
#  'org.eclipse.ocl.edit.source.feature.jar': ['5.10.1.v20191014-1354', '1.0.0'],
#  'org.eclipse.gef.cloudio.ui.feature.jar': ['5.0.2.201910161621', '1.0.0'],
#  'org.eclipse.qvtd.examples': ['1.0.0', '0.21.0.v20191016-1944', '0.0.0'],
#  'org.eclipse.viatra.addon.querybasedfeatures.runtime.feature.source.feature.group': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.gef.mvc.fx.ui.source.feature.group': ['5.1.1.201910161621',
#   '1.0.0'],
#  'org.eclipse.m2e.editor.xml.source': ['1.13.0.20190716-1624', '1.0.0'],
#  'Linux Tools': ['0.0.0.7D79-cLSQZ27735K3K5535CI'],
#  'org.eclipse.gmf.runtime.diagram.ui.providers.ide': ['1.7.0.201905141505',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emfforms.ide.builder.source': ['1.23.0.20191007-1207', '1.0.0'],
#  'org.eclipse.emf.compare.uml2.feature.group': ['3.3.8.201909101346', '1.0.0'],
#  'org.eclipse.e4.ui.css.core.source': ['1.0.0', '0.12.900.v20191007-1125'],
#  'org.eclipse.jdt.annotation': ['2.2.300.v20190328-1431', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.ecp.e3.feature.source.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.emf.query.doc.feature.jar': ['1.12.0.201805030653', '1.0.0'],
#  'org.eclipse.uml2.uml.resources': ['5.5.0.v20181203-1331', '1.0.0', '0.0.0'],
#  'org.eclipse.net4j.util.ui.feature.group': ['4.7.0.v20180530-0909', '1.0.0'],
#  'org.eclipse.jdt.compiler.apt': ['1.3.800.v20190919-0948', '1.0.0', '0.0.0'],
#  'org.eclipse.gef.geometry.convert.fx.source.feature.jar': ['5.0.0.201910161621',
#   '1.0.0'],
#  'org.eclipse.equinox.p2.extras.feature.feature.jar': ['1.4.600.v20191008-0645',
#   '1.0.0'],
#  'org.eclipse.emf.transaction.sdk.feature.group': ['1.12.0.201805140824',
#   '1.0.0'],
#  'com.ibm.icu': ['64.2.0.v20190507-1337', '64.2.0', '1.0.0'],
#  'org.eclipse.ocl.examples.unified.source.feature.jar': ['4.10.0.v20191014-1354',
#   '1.0.0'],
#  'org.eclipse.jpt.jpa.eclipselink.core.ddlgen': ['2.2.201.v201902121834',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.wst.xsl.exslt.core': ['1.1.0.v201901071922', '1.0.0', '0.0.0'],
#  'org.eclipse.mat.api': ['1.9.1.201908260659', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.infra.emf.expressions.edit': ['1.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.transaction.examples': ['1.2.100.201805140824',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.mylyn.wikitext.confluence.ui.source': ['3.0.33.201907111840',
#   '1.0.0'],
#  'org.eclipse.birt.chart.device.pdf.source': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.datatools.common.doc.user.feature.group': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.linuxtools.docker.core': ['4.5.0.201910151606',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.viatra.transformation.runtime.emf.feature.feature.jar': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.cdt.dsf.gdb.multicorevisualizer.ui': ['1.1.100.201908121111',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.equinox.p2.console.source': ['1.1.300.v20191002-0702', '1.0.0'],
#  'org.eclipse.equinox.event': ['1.5.300.v20191001-1333',
#   '1.4.0',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.m2e.sourcelookup.ui': ['1.13.0.20190716-1624', '1.0.0'],
#  'org.eclipse.e4.ui.di.source': ['1.2.700.v20190930-1643', '1.0.0'],
#  'org.eclipse.papyrus.infra.emf.expressions.editor': ['1.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.egf.model.editor': ['1.6.1.201910041425', '1.0.0', '0.0.0'],
#  'org.slf4j.api': ['1.7.2.v20121108-1250', '1.7.2', '1.0.0'],
#  'org.eclipse.e4.core.contexts.source': ['1.8.300.v20190916-2125', '1.0.0'],
#  'org.eclipse.eclemma.doc': ['3.1.2.201903112331', '1.0.0'],
#  'org.eclipse.datatools.enablement.hsqldb.feature.feature.group': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.view.table.model.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.mylyn.commons.notifications.feature.jar': ['1.16.0.v20180904-2231',
#   '1.0.0'],
#  'org.eclipse.egf.portfolio.task.ant': ['1.6.1.201910041425',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.datatools.sqldevtools.feature.feature.jar': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.qvtd.master.source.feature.group': ['1.0.0',
#   '0.21.0.v20191016-1944'],
#  'org.eclipse.emf.ecoretools.design.ui': ['3.3.2.201909230743',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.changelog.c.feature.group': ['7.5.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.emf.util.source': ['3.9.0.v20191014-1442', '1.0.0'],
#  'org.eclipse.ecf.provider.filetransfer.source': ['3.2.400.v20180306-0429',
#   '1.0.0'],
#  'org.eclipse.pde.source.feature.jar': ['3.14.200.v20191009-1800', '1.0.0'],
#  'org.eclipse.wst.jsdt.chromium.wip.eclipse': ['1.0.0',
#   '0.5.200.v201903222101',
#   '0.0.0'],
#  'org.eclipse.papyrus.infra.gmfdiag.css.configuration': ['2.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jdt.junit.source': ['3.11.600.v20191008-0011', '1.0.0'],
#  'org.eclipse.datatools.sqltools.db.derby.ui': ['1.2.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.gef.common.sdk.feature.group': ['5.0.1.201910161621', '1.0.0'],
#  'org.eclipse.pde.api.tools': ['1.1.1000.v20190929-1236', '1.0.0', '0.0.0'],
#  'org.eclipse.linuxtools.docker.ui.source': ['4.5.0.201910151606', '1.0.0'],
#  'org.eclipse.epp.mpc.ui': ['1.8.0.v20190725-1807', '1.0.0', '0.0.0'],
#  'org.eclipse.xtext.activities': ['2.20.0.v20191014-0620', '1.0.0', '0.0.0'],
#  'org.eclipse.passage.lic.products.e4.ui': ['1.0.0', '0.5.0.v20190904-1720'],
#  'org.eclipse.jst.servlet.ui.infopop': ['1.0.500.v201903222024', '1.0.0'],
#  'org.eclipse.emf.ecp.workspace.ui.source': ['1.23.0.20191007-1207', '1.0.0'],
#  'org.eclipse.emf.feature.jar': ['2.20.0.v20190920-0412', '1.0.0'],
#  'org.eclipse.mylyn.github.feature.feature.jar': ['5.5.0.201909110433-r',
#   '1.0.0'],
#  'org.eclipse.passage.lic.e4.core': ['1.0.0', '0.5.0.v20190904-1720', '0.0.0'],
#  'org.eclipse.papyrus.infra.tools': ['3.2.0.201910160941', '1.0.0', '0.0.0'],
#  'org.eclipse.rap.demo.controls': ['3.11.0.20190917-1349', '3.11.0', '1.0.0'],
#  'org.eclipse.tcf.cdt.ui': ['1.6.1.201907191905', '1.0.0', '0.0.0'],
#  'org.apache.batik.css.source': ['1.6.0.v201011041432', '1.0.0'],
#  'org.eclipse.emf.ecore.xcore.importer': ['1.5.0.v20190323-1031',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.php.composer.feature.jar': ['7.0.0.201910101950', '1.0.0'],
#  'org.eclipse.epp.mpc.feature.jar': ['1.8.0.v20190725-1807', '1.0.0'],
#  'org.eclipse.papyrus.infra.ui.feature.feature.group': ['3.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.papyrus.infra.services.labelprovider': ['2.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.m2m.atl.examples.source': ['4.1.0.v201909021645', '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.tools.coverage.junit.feature.jar': ['1.6.1.v20191014-1442',
#   '1.0.0'],
#  'org.eclipse.e4.ui.workbench.addons.swt': ['1.3.700.v20190927-0635',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.passage.lic.jface': ['1.0.0', '0.6.0.v20190904-1720', '0.0.0'],
#  'org.eclipse.birt.report.data.oda.jdbc.dbprofile.ui.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.linuxtools.cdt.libhover.devhelp.feature.feature.jar': ['7.5.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.birt.chart.device.pdf': ['4.7.0.v201706222054',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.cdo.explorer': ['4.5.200.v20180529-1130',
#   '4.5.200',
#   '1.0.0'],
#  'org.eclipse.ptp.debug.sdm.core': ['7.0.0.201909101427', '1.0.0', '0.0.0'],
#  'org.eclipse.e4.emf.xpath': ['1.0.0', '0.2.500.v20190926-0808', '0.0.0'],
#  'org.eclipse.m2e.refactoring.source': ['1.13.0.20190716-1624', '1.0.0'],
#  'org.eclipse.birt.report.data.oda.xml.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.m2m.atl.examples.feature.group': ['4.1.0.v201909021645',
#   '1.0.0'],
#  'org.eclipse.mylyn.team_feature.feature.group': ['3.24.2.v20180905-0014',
#   '1.0.0'],
#  'org.w3c.sac': ['1.3.0.v201706222054', '1.0.0', '0.0.0'],
#  'org.eclipse.linuxtools.tools.launch.core.source': ['3.3.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.draw2d.doc.isv': ['3.10.100.201606061308', '1.0.0'],
#  'org.eclipse.gef.cloudio.doc': ['5.0.2.201910161621', '1.0.0'],
#  'org.eclipse.graphiti.examples.composite.source': ['1.0.0',
#   '0.16.1.201909061426'],
#  'org.eclipse.cdt.gnu.debug.source.feature.jar': ['9.9.0.201908121431',
#   '1.0.0'],
#  'org.eclipse.gmf.runtime.notation.edit': ['1.7.0.201805221301',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.common.source.feature.jar': ['2.17.0.v20190920-0401',
#   '1.0.0'],
#  'org.eclipse.remote.proxy.protocol.core': ['2.0.0.201909031456',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jst.server.tomcat.core': ['1.1.902.v201901310132',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.gprof.launch.source': ['1.2.0.201910151606', '1.0.0'],
#  'org.eclipse.e4.tools.services.source': ['4.8.300.v20190708-1118', '1.0.0'],
#  'org.eclipse.ecf.discovery.slp.feature.feature.jar': ['1.0.0.v20181107-1631',
#   '1.0.0'],
#  'org.eclipse.xtext.docs.feature.jar': ['2.20.0.v20191014-0836', '1.0.0'],
#  'org.eclipse.cdt.qt.core': ['2.2.200.201908101428', '1.0.0', '0.0.0'],
#  'org.eclipse.mylyn.commons.notifications.core.source': ['1.16.0.v20180904-2231',
#   '1.0.0'],
#  'org.eclipse.uml2.doc': ['5.5.0.v20181203-1331', '1.0.0'],
#  'toolingorg.eclipse.sdk.configuration': ['1.0.0'],
#  'org.eclipse.net4j.db.h2.feature.group': ['4.3.100.v20180529-1130', '1.0.0'],
#  'org.eclipse.linuxtools.vagrant.ui.source': ['2.0.0.201910151606', '1.0.0'],
#  'org.eclipse.gmf.runtime.diagram.ui.geoshapes.source': ['1.7.0.201905141505',
#   '1.0.0'],
#  'toolingorg.eclipse.sdk.ide.config.gtk.linux.ppc64le': ['4.14.0.I20191009-1800'],
#  'org.eclipse.swtbot.generator.ui': ['2.8.0.201906121535', '1.0.0'],
#  'org.apache.batik.util.gui': ['1.6.0.v201011041432', '1.6.0', '1.0.0'],
#  'org.eclipse.m2m.atl': ['4.1.0.v201909021645', '1.0.0'],
#  'org.eclipse.wb.swing.FormLayout.lib': ['1.9.1.201812270937',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.rse.subsystems.files.ssh': ['4.5.100.201901312252',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.ecf.source': ['3.9.3.v20190423-0625', '1.0.0'],
#  'org.eclipse.dltk.tcl.debug.ui': ['6.0.0.201909210130', '1.0.0', '0.0.0'],
#  'org.junit.jupiter.params': ['5.5.1.v20190826-0900', '5.5.1', '1.0.0'],
#  'org.eclipse.emf.eef.mapping.edit.source': ['1.5.1.201601141612', '1.0.0'],
#  'org.eclipse.birt.osgi.runtime.feature.group': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.rse.doc.user': ['4.5.100.201901312252', '1.0.0'],
#  'org.eclipse.emf.compare': ['3.5.3.201909101346', '1.0.0', '0.0.0'],
#  'org.eclipse.oomph.targlets.edit': ['1.5.0',
#   '1.10.0.v20180706-1242',
#   '1.0.0'],
#  'org.eclipse.qvtd.xtext.qvtcore': ['1.0.0', '0.21.0.v20191016-1944', '0.0.0'],
#  'org.eclipse.papyrus.emf.facet.custom.metamodel': ['1.4.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.apache.batik.transcoder': ['1.6.0.v201011041432', '1.6.0', '1.0.0'],
#  'org.eclipse.emf.ecp.view.categorization.model.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.view.group.model': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.jubula.launch.ui': ['8.0.0.201909100722', '1.0.0', '0.0.0'],
#  'org.eclipse.ptp.etfw.doc.user': ['1.0.0.201909101427', '1.0.0'],
#  'org.eclipse.m2m.atl.adt.debug': ['4.1.0.v201909021645', '1.0.0', '0.0.0'],
#  'org.eclipse.m2e.wtp.overlay.ui': ['1.4.2.20190530-0057', '1.0.0'],
#  'org.eclipse.gmf.runtime.common.ui.action.ide': ['1.7.0.201905141505',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.mylyn.github.ui': ['5.5.0.201909110433-r', '5.5.0', '1.0.0'],
#  'org.eclipse.viatra.addon.validation.runtime.feature.feature.group': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.jst.server.tomcat.ui': ['1.1.600.v201901310132',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.wst.jsdt.feature.feature.jar': ['2.1.3.v201908270117', '1.0.0'],
#  'org.eclipse.emf.oda.sdk.feature.group': ['1.8.0.v20190625-1131', '1.0.0'],
#  'org.eclipse.jem.util': ['2.1.201.v201903222010', '1.0.0', '0.0.0'],
#  'org.eclipse.ocl.uml.feature.group': ['5.10.1.v20191014-1354', '1.0.0'],
#  'org.eclipse.emf.eef.codegen.extended': ['1.5.1.201601141612',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jpt.jaxb.eclipselink.feature.feature.group': ['1.4.202.v201903221940',
#   '1.0.0'],
#  'org.eclipse.emf.cdo.expressions.edit.source': ['4.3.300.v20180529-1130',
#   '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.runtime': ['3.9.2.v20191014-1442', '1.0.0', '0.0.0'],
#  'org.eclipse.tips.ide': ['1.0.0', '0.1.700.v20190914-0158', '0.0.0'],
#  'org.eclipse.gef.mvc.fx.ui': ['5.1.1.201910161621', '1.0.0', '0.0.0'],
#  'org.eclipse.mylyn.java.tasks.source': ['3.24.2.v20180905-0014', '1.0.0'],
#  'org.w3c.dom.smil.source': ['1.0.1.v200903091627', '1.0.0'],
#  'org.eclipse.papyrus.emf.facet.util.emf.core': ['1.2.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.viatra.query.runtime.feature.feature.group': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.net4j.util.ui.feature.jar': ['4.7.0.v20180530-0909', '1.0.0'],
#  'org.eclipse.ptp.rm.ibm.ll.doc.user': ['4.0.0.201909101427', '1.0.0'],
#  'org.eclipse.datatools.enablement.sdk.feature.feature.group': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.launchbar.ui.controls': ['1.0.100.201907192018',
#   '1.0.0',
#   '0.0.0'],
#  'org.slf4j.api.source': ['1.7.2.v20121108-1250', '1.0.0'],
#  'org.eclipse.objectteams.otdt.debug.adaptor': ['2.7.5.201909081329',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.ecore.edit.source.feature.jar': ['2.14.0.v20190822-1451',
#   '1.0.0'],
#  'org.eclipse.mylyn.builds.core.source': ['1.16.0.v20170629-2231', '1.0.0'],
#  'org.eclipse.team.cvs.core': ['3.4.800.v20190925-1852', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.ecp.view.validation.initial.feature.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.birt.report.model': ['4.7.0.v201706222054', '1.0.0', '0.0.0'],
#  'org.eclipse.gmf.runtime.diagram.ui.providers.source': ['1.7.0.201905141505',
#   '1.0.0'],
#  'org.eclipse.equinox.p2.ui': ['2.5.700.v20190930-1517',
#   '2.0.0',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.papyrus.uml.decoratormodel.doc': ['1.2.0.201910160941', '1.0.0'],
#  'org.eclipse.papyrus.infra.internationalization.common': ['1.100.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.gcov.docs': ['1.0.0.201910151606', '1.0.0'],
#  'org.eclipse.datatools.sqltools.routineeditor.ui': ['1.2.101.201811012051',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.egf.portfolio.type': ['1.6.1.201910041425', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.ecp.view.label.model.edit.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.papyrus.emf': ['1.0.0.201910160941', '1.0.0', '0.0.0'],
#  'org.eclipse.cdt.managedbuilder.ui': ['9.1.300.201908090550',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.xsd.ecore.converter': ['2.8.0.v20180706-1143', '1.0.0'],
#  'org.eclipse.qvtd.pivot.qvtschedule.source': ['1.0.0',
#   '0.21.0.v20191016-1944'],
#  'org.eclipse.gef.cloudio.doc.feature.group': ['5.0.2.201910161621', '1.0.0'],
#  'org.eclipse.mylyn.versions.ui': ['1.16.0.v20170629-1738', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.ecp.feature.source.feature.jar': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.cdt.codan.checkers.source': ['3.3.200.201908101428', '1.0.0'],
#  'org.eclipse.emf.mwe2.launch': ['2.11.1.M1', '1.0.0', '0.0.0'],
#  'org.eclipse.birt.report.designer.ui.samples.ide': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.ecf.eventadmin.feature.source.feature.jar': ['2.0.100.v20181107-1749',
#   '1.0.0'],
#  'org.eclipse.ltk.ui.refactoring.source': ['3.10.100.v20191008-0011', '1.0.0'],
#  'com.github.jnr.posix': ['3.0.35.v20180207-1730', '3.0.35', '1.0.0'],
#  'org.eclipse.emf.ecp.view.edapt.feature.feature.jar': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.mylyn.gerrit.dashboard.feature.feature.jar': ['2.15.0.v20170629-2231',
#   '1.0.0'],
#  'org.eclipse.equinox.p2.publisher.eclipse.source': ['1.3.400.v20191002-0702',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.feature.source.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.remote.jsch.ui': ['1.0.0.201909031456', '1.0.0', '0.0.0'],
#  'org.eclipse.cdt.debug.ui.source': ['8.3.200.201908121111', '1.0.0'],
#  'org.eclipse.equinox.p2.rcp.feature.source.feature.jar': ['1.4.600.v20191008-0645',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.view.categorization.feature.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.jdt.annotation.source': ['2.2.300.v20190328-1431', '1.0.0'],
#  'org.eclipse.wst.jsdt.chromium.debug.jsdtbridge': ['1.0.0',
#   '0.5.200.v201903222101'],
#  'org.eclipse.emfforms.core.services.locale.default': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.view.validation.feature.source.feature.jar': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.tools.coverage.doc.source': ['1.5.0.v20191014-1442',
#   '1.0.0'],
#  'org.eclipse.mylyn.builds.ui': ['1.16.0.v20170629-2231', '1.0.0', '0.0.0'],
#  'org.eclipse.datatools.sqltools.sqlscrapbook': ['1.2.101.201811012051',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.papyrus.views.validation.feature.feature.group': ['2.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.birt.report.designer.editor.xml.wtp.feature.jar': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.equinox.core.feature.feature.group': ['1.11.0.v20191008-0645',
#   '1.0.0'],
#  'org.eclipse.xpand.activities.source': ['2.2.0.v201605260315', '1.0.0'],
#  'org.eclipse.egf.model.feature.feature.jar': ['1.6.1.201910041425', '1.0.0'],
#  'org.eclipse.jsch.ui.source': ['1.3.700.v20190925-1852', '1.0.0'],
#  'org.eclipse.qvtd.pivot.qvtrelation': ['1.0.0',
#   '0.21.0.v20191016-1944',
#   '0.0.0'],
#  'org.eclipse.wtp.epp.package.jee.intro': ['1.3.0.v201902122017', '1.0.0'],
#  'org.eclipse.emf.mapping.ecore.editor.source.feature.group': ['2.14.0.v20190528-0725',
#   '1.0.0'],
#  'org.eclipse.lsp4j.websocket': ['1.0.0', '0.8.0.v20190822-0801'],
#  'org.eclipse.dltk.ruby.launching': ['6.0.0.201909210130', '1.0.0', '0.0.0'],
#  'org.eclipse.e4.tools.jdt.templates.source': ['4.8.400.v20191001-0504',
#   '1.0.0'],
#  'org.eclipse.cdt.testsrunner.feature.feature.jar': ['9.9.0.201908121431',
#   '1.0.0'],
#  'org.eclipse.gmf.runtime.common.ui.services.dnd.ide': ['1.7.0.201905141505',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.ecf.filetransfer.feature.feature.group': ['3.14.5.v20190423-0614',
#   '1.0.0'],
#  'com.github.jnr.ffi': ['2.1.4.v20180207-1730', '2.1.4', '1.0.0'],
#  'org.eclipse.linuxtools.valgrind.massif.source': ['1.1.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.ocl.common.ui': ['1.8.400.v20191014-1354', '1.0.0', '0.0.0'],
#  'org.eclipse.e4.core.tools.feature.source.feature.jar': ['4.14.0.v20191001-0938',
#   '1.0.0'],
#  'org.eclipse.reddeer.uiforms': ['2.8.0.v20191016-1718', '1.0.0', '0.0.0'],
#  'org.eclipse.reddeer.e4.feature.feature.group': ['2.8.0.v20191016-1718',
#   '1.0.0'],
#  'org.eclipse.emf.cdo.ui.compare': ['4.4.200.v20180529-1130',
#   '4.4.200',
#   '1.0.0'],
#  'org.eclipse.rcptt.verifications.text': ['2.4.2.201903220647',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.gcov.source.feature.group': ['7.5.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.linuxtools.rpm.createrepo': ['1.0.0.201910151606', '1.0.0'],
#  'org.eclipse.ocl.xtext.completeocl.ui.source': ['1.10.0.v20191014-1354',
#   '1.0.0'],
#  'org.eclipse.emf.validation.feature.jar': ['1.12.1.201812070911', '1.0.0'],
#  'org.eclipse.rap.tools.launch': ['3.11.0.20190917-1349', '1.0.0', '0.0.0'],
#  'org.eclipse.xtext.xbase.lib.feature.group': ['2.20.0.v20191014-0341',
#   '1.0.0'],
#  'org.eclipse.platform.sdk.executable.gtk.linux.x86_64.eclipse': ['4.14.0.I20191009-1800'],
#  'org.eclipse.emf.ecp.view.viewproxy.model': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.eef': ['2.1.2.201903071543', '2.0.0', '1.0.0'],
#  'org.eclipse.oomph.setup.mylyn.feature.group': ['1.14.0.v20190920-0437',
#   '1.0.0'],
#  'org.eclipse.papyrus.infra.newchild.editor': ['3.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.birt.report.designer.ui.data': ['4.7.0.v201706222054',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.e4.ui.di': ['1.2.700.v20190930-1643', '1.0.0', '0.0.0'],
#  'org.eclipse.ocl.edit.feature.jar': ['5.10.1.v20191014-1354', '1.0.0'],
#  'org.eclipse.rap.filedialog': ['3.11.0.20190917-1349', '3.11.0', '1.0.0'],
#  'org.eclipse.jubula.client.autagent': ['8.0.0.201909100722',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.rcptt.util.swt': ['2.4.2.201903220647', '1.0.0', '0.0.0'],
#  'org.eclipse.xtext.common.types.source': ['2.20.0.v20191014-0549', '1.0.0'],
#  'Database Development': ['0.0.0.0--cLdIiI'],
#  'org.eclipse.jst.ws.creation.ejb.ui': ['1.0.250.v201903050508', '1.0.0'],
#  'org.eclipse.dltk.tcl.feature.jar': ['6.0.0.201909210130', '1.0.0'],
#  'org.eclipse.tracecompass.analysis.counters.core': ['2.0.2.201909110900',
#   '1.0.0',
#   '0.0.0'],
#  'org.apache.lucene.core': ['8.0.0.v20190404-1858', '8.0.0', '1.0.0'],
#  'org.eclipse.ecf.ssl.source': ['1.2.200.v20190502-0212', '1.0.0'],
#  'org.eclipse.emf.ecp.emfforms.runtime.feature.source.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.ocl.examples.debug.ui.source': ['2.10.0.v20191014-1354',
#   '1.0.0'],
#  'org.eclipse.emf.codegen.ecore.feature.jar': ['2.20.0.v20190920-0412',
#   '1.0.0'],
#  'org.eclipse.jst.jsf.core': ['1.8.2.v201902121810', '1.0.0', '0.0.0'],
#  'org.eclipse.rcptt.external.dependencies.feature.feature.group': ['2.4.2.201903220647',
#   '1.0.0'],
#  'org.eclipse.birt.report.engine.dataextraction.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.mylyn.bugzilla.ide.source': ['3.24.2.v20180905-0014', '1.0.0'],
#  'org.eclipse.emf.ecp.view.horizontal.ui.swt': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.ecf.provider.generic.remoteservice.feature.feature.group': ['1.1.100.v20180516-2213',
#   '1.0.0'],
#  'org.eclipse.mylyn.ide_feature.feature.jar': ['3.24.2.v20180905-0014',
#   '1.0.0'],
#  'org.eclipse.oomph.workingsets.feature.group': ['1.12.0.v20190929-1544',
#   '1.0.0'],
#  'org.eclipse.viatra.query.runtime.feature.feature.jar': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.rcptt.updates.extra': ['2.4.2.201903220647', '1.0.0'],
#  'org.eclipse.papyrus.uml.internationalization': ['1.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jubula.client.api': ['3.5.0.201909100722', '1.0.0', '0.0.0'],
#  'org.eclipse.m2m.qvt.oml.examples.feature.jar': ['3.10.1.v20191014-1442',
#   '1.0.0'],
#  'org.eclipse.qvtd.xtext.qvtimperative.source': ['1.0.0',
#   '0.21.0.v20191016-1944'],
#  'org.eclipse.emf.ecp.view.label.model': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.jwt.we.conf.model': ['1.6.0.201605250940', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.uml.alf.libraries': ['2.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.tcf.te.tcf.processes.core': ['1.6.1.201907191905',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.php.mylyn.feature.jar': ['7.0.0.201910101950', '1.0.0'],
#  'org.eclipse.emf.ecp.view.core.swt': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.viatra.query.runtime.rete': ['2.3.0.201910160845',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.compare.egit.ui': ['1.1.3.201909101346', '1.0.0', '0.0.0'],
#  'org.eclipse.dltk.ruby.testing': ['6.0.0.201909210130', '1.0.0', '0.0.0'],
#  'org.eclipse.jdt.feature.jar': ['3.18.200.v20191009-1800', '1.0.0'],
#  'org.eclipse.egf.core.pde': ['1.6.1.201910041425', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.query.feature.group': ['1.12.0.201805030653', '1.0.0'],
#  'org.eclipse.emf.mwe.core.feature.feature.jar': ['1.5.1.M1', '1.0.0'],
#  'org.eclipse.datatools.intro': ['1.14.101.201811012051', '1.0.0'],
#  'org.eclipse.equinox.security.win32.x86_64': ['1.1.200.v20190812-0919',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jpt.jpa.gen': ['2.3.201.v201902121834', '1.0.0', '0.0.0'],
#  'org.eclipse.launchbar.remote.feature.group': ['2.4.0.201907192018', '1.0.0'],
#  'org.eclipse.papyrus.infra.emf.gmf': ['1.3.0.201910160941', '1.0.0', '0.0.0'],
#  'org.eclipse.m2m.atl.engine.source': ['4.1.0.v201909021645', '1.0.0'],
#  'org.eclipse.jwt.we.example': ['1.6.0.201605250940', '1.0.0', '0.0.0'],
#  'org.eclipse.bpel.xpath10': ['1.1.2.Final-v20180621-1835', '1.0.0', '0.0.0'],
#  'org.eclipse.jst.ws.jaxws.dom.runtime': ['1.0.301.v201902162228',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jgit.junit.source': ['5.5.0.201909110433-r', '1.0.0'],
#  'org.eclipse.papyrus.views.properties.feature.feature.jar': ['3.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.papyrus.emf.facet.query.ocl.core': ['1.2.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.gmf.runtime.common.ui.services.dnd': ['1.7.0.201905141505',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.cdt.libhover.devhelp.feature.source.feature.jar': ['7.5.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.qvtd.doc.source': ['1.0.0', '0.21.0.v20191016-1944'],
#  'org.eclipse.m2e.refactoring': ['1.13.0.20190716-1624', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.cdo.compare.feature.group': ['4.4.200.v20180529-1130',
#   '1.0.0'],
#  'org.eclipse.jem.workbench': ['2.0.400.v201903222024', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.infra.emf.nattable': ['5.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.dltk.itcl': ['6.0.0.201909210130', '1.0.0'],
#  'org.eclipse.core.net.linux.x86_64.source': ['1.2.400.v20190924-1023',
#   '1.0.0'],
#  'org.eclipse.passage.lic.emf': ['1.0.0', '0.5.0.v20190904-1720', '0.0.0'],
#  'org.eclipse.linuxtools.binutils.source': ['6.0.0.201910151606', '1.0.0'],
#  'org.eclipse.equinox.http.jetty': ['3.7.200.v20190714-1849',
#   '1.5.0',
#   '1.0.0'],
#  'org.eclipse.platform.source.feature.jar': ['4.14.0.v20191009-1800', '1.0.0'],
#  'toolingorg.eclipse.platform.sdk.config.win32.win32.x86_64': ['4.14.0.I20191009-1800'],
#  'org.eclipse.jetty.jndi': ['9.4.5.v20170502', '9.4.5', '1.0.0'],
#  'org.eclipse.rcptt.tesla.feature.group': ['2.4.2.201903220647', '1.0.0'],
#  'org.eclipse.rap.ui.cheatsheets.source': ['3.11.0.20190917-1349', '1.0.0'],
#  'org.eclipse.jst.jsf.standard.tagsupport': ['1.5.1.v201902121810',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.rse.importexport': ['4.5.101.201904091623', '1.0.0', '0.0.0'],
#  'org.eclipse.datatools.enablement.sqlite.dbdefinition': ['1.2.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.libra.facet.feature.feature.group': ['1.0.0',
#   '0.3.1.201609011955'],
#  'org.eclipse.equinox.executable_root.gtk.linux.ppc64le': ['3.8.600.v20190924-0505'],
#  'org.eclipse.libra.warproducts.ui': ['1.0.0', '0.3.1.201609011955', '0.0.0'],
#  'org.eclipse.swtbot.eclipse.gef.finder': ['2.8.0.201906121535',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emfforms.swt.treemasterdetail.decorator.validation.default.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.cdt.debug.ui.memory.transport': ['2.1.100.201908121111',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.valgrind.cachegrind': ['1.1.0.201910151606', '1.0.0'],
#  'org.eclipse.viatra.query.runtime': ['2.3.0.201910160845', '1.0.0', '0.0.0'],
#  'org.eclipse.e4.tools.source': ['4.8.600.v20191001-0938', '1.0.0'],
#  'org.eclipse.birt.chart.engine.extension.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.ecf.discovery.zookeeper.feature.source.feature.group': ['1.0.0.v20180302-2006',
#   '1.0.0'],
#  'org.eclipse.gmf.runtime.diagram.ui.geoshapes': ['1.7.0.201905141505',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.papyrus.uml.search.feature.feature.group': ['2.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.papyrus.infra.internationalization.feature.feature.jar': ['1.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.jst.server_adapters.feature.feature.jar': ['3.2.500.v201901310132',
#   '1.0.0'],
#  'org.eclipse.papyrus.infra.types.core': ['4.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.egit.github.core': ['5.5.0.201909110433-r', '5.5.0', '1.0.0'],
#  'org.eclipse.jst.jsp.ui.infopop': ['1.0.200.v201903222120', '1.0.0'],
#  'org.eclipse.dltk.ruby.feature.jar': ['6.0.0.201909210130', '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.sdk.feature.jar': ['3.10.1.v20191014-1442', '1.0.0'],
#  'org.eclipse.datatools.enablement.oda.xml.ui': ['1.4.101.201811012051',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.rse.subsystems.files.local': ['4.5.100.201901312252',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.m2m.qvt.oml.runtime.feature.group': ['3.10.1.v20191014-1442',
#   '1.0.0'],
#  'org.eclipse.ui.win32': ['3.4.300.v20190926-0808', '1.0.0', '0.0.0'],
#  'org.eclipse.ptp.pldt.openshmem': ['6.0.0.201909101427', '1.0.0', '0.0.0'],
#  'org.eclipse.mylyn.bugzilla.ide': ['3.24.2.v20180905-0014', '1.0.0'],
#  'org.eclipse.emfforms.core.services.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.emf.compare.uml2.ide': ['3.3.1.201909101346', '1.0.0'],
#  'org.eclipse.jpt.jpa.feature.feature.group': ['3.5.101.v201903221940',
#   '1.0.0'],
#  'org.eclipse.acceleo.query': ['6.0.8.201902261618',
#   '5.0.1',
#   '5.0.0',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.pde.build.source': ['3.10.600.v20191001-0444', '1.0.0'],
#  'org.eclipse.passage.lic.products.migration': ['1.0.0',
#   '0.5.0.v20190904-1720'],
#  'org.eclipse.m2m.atl.profiler.model.source': ['4.1.0.v201909021645', '1.0.0'],
#  'org.eclipse.papyrus.uml.diagram.interactionoverview': ['3.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.qvtd.examples.feature.jar': ['1.0.0', '0.21.0.v20191016-1944'],
#  'org.eclipse.jubula.client.api.commands': ['4.0.0.201909100722', '1.0.0'],
#  'org.eclipse.emf.ecp.ui.view.editor.controls.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.jst.enterprise_ui.feature.feature.group': ['3.15.0.v201908261515',
#   '1.0.0'],
#  'org.eclipse.cdt.managedbuilder.xlupc.ui.source': ['1.1.1.201811241055',
#   '1.0.0'],
#  'org.eclipse.birt': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.jetty.servlet.source': ['9.4.21.v20190926', '1.0.0'],
#  'org.eclipse.emf.ecore.xcore': ['1.12.0.v20190924-0817', '1.0.0', '0.0.0'],
#  'org.eclipse.ecf.provider.generic.remoteservice.feature.source.feature.group': ['1.1.100.v20180516-2213',
#   '1.0.0'],
#  'org.eclipse.platform_root': ['4.14.0.v20191009-1800'],
#  'org.eclipse.papyrus.emf.facet.custom.ui': ['3.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.viatra.query.language.feature.source.feature.group': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.papyrus.infra.services.navigation': ['3.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.viatra.transformation.views.source': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.emf.cdo.server.net4j.source': ['4.1.500.v20180530-1201',
#   '1.0.0'],
#  'org.eclipse.emf.cdo.server.product.source': ['4.1.600.v20180529-1130',
#   '1.0.0'],
#  'org.eclipse.linuxtools.man.core': ['1.5.0.201910151606', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.cdo.server.mongodb.source': ['4.0.600.v20180529-1130',
#   '1.0.0'],
#  'org.eclipse.ant.core': ['3.5.600.v20190914-1928', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.emf.facet.efacet.sdk.ui': ['2.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.xtext.ui.testing': ['2.20.0.v20191014-0620', '1.0.0', '0.0.0'],
#  'org.eclipse.datatools.enablement.oracle.feature.feature.jar': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.demo.e3.feature.source.feature.jar': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.papyrus.uml.commands': ['1.3.100.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.papyrus.infra.nattable.views.editor': ['1.2.100.201910160941',
#   '1.0.0'],
#  'org.eclipse.datatools.connectivity.feature.feature.jar': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.tracecompass.doc.dev': ['5.1.0.201909110900', '1.0.0'],
#  'org.eclipse.ecf.discovery.slp.feature.source.feature.group': ['1.0.0.v20181107-1631',
#   '1.0.0'],
#  'toolingorg.eclipse.platform.configuration': ['1.0.0'],
#  'org.eclipse.gef.fx.swt.source': ['5.0.2.201910161621', '1.0.0'],
#  'org.eclipse.wst.common.core': ['1.3.0.v201903222010', '1.0.0', '0.0.0'],
#  'org.eclipse.oomph.setup.p2.edit': ['1.5.0',
#   '1.11.0.v20190702-1454',
#   '1.0.0'],
#  'org.eclipse.linuxtools.rpm.createrepo.source': ['1.0.0.201910151606',
#   '1.0.0'],
#  'toolinggtk.linux.ppc64leorg.apache.felix.scr': ['4.14.0.I20191009-1800',
#   '1.0.0'],
#  'org.eclipse.rcptt.core.scenario': ['2.4.2.201903220647', '1.0.0', '0.0.0'],
#  'org.eclipse.mylyn.commons.identity.core': ['1.16.0.v20180904-2231',
#   '1.0.0',
#   '0.0.0'],
#  'org.apache.xmlgraphics.source': ['2.3.0.v20190515-0436', '1.0.0'],
#  'org.eclipse.ecf.provider.bittorrent.source': ['1.0.0',
#   '0.3.300.v20180302-2006'],
#  'org.eclipse.birt.report.data.adapter.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.jubula.toolkit.swing.api.source': ['5.0.0.201909100722',
#   '1.0.0'],
#  'org.eclipse.emf.ecoretools.design.feature.group': ['3.3.2.201909230743',
#   '1.0.0'],
#  'org.eclipse.mylyn.cvs.core': ['1.16.0.v20170629-1738', '1.0.0', '0.0.0'],
#  'org.eclipse.ecf.remoteservice.rest.feature.source.feature.jar': ['1.0.100.v20180302-2006',
#   '1.0.0'],
#  'org.eclipse.sirius.editor': ['6.2.3.201908120659',
#   '6.1.0',
#   '6.0.0',
#   '5.0.0',
#   '3.1.3',
#   '3.1.0',
#   '3.0.0',
#   '2.1.0',
#   '2.0.4',
#   '2.0.0',
#   '1.0.0'],
#  'org.eclipse.cft.server.rse': ['1.0.1.v201805291812', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.uml.internationalization.edit': ['1.100.100.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.datatools.enablement.sdk.feature.feature.jar': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.eef.core.ext.widgets.reference': ['2.1.2.201903071543',
#   '2.0.0',
#   '1.0.0'],
#  'org.eclipse.equinox.p2.core.feature.feature.jar': ['1.6.400.v20191008-0645',
#   '1.0.0'],
#  'org.eclipse.wst.xsdeditor.doc.user': ['1.0.800.v201903222120', '1.0.0'],
#  'org.eclipse.ocl.xtext.oclstdlib.source': ['1.10.0.v20191014-1354', '1.0.0'],
#  'org.eclipse.wst.server.ui.doc.user': ['1.1.600.v201901310132', '1.0.0'],
#  'org.eclipse.graphiti.feature.feature.jar': ['1.0.0', '0.16.1.201909061426'],
#  'org.eclipse.tracecompass.tmf.pcap.feature.group': ['5.1.0.201909110900',
#   '1.0.0'],
#  'org.eclipse.birt.report.engine.emitter.config.ods.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'com.fasterxml.jackson.jaxrs.jackson-jaxrs-json-provider': ['2.9.2.v20180207-1730',
#   '2.9.2',
#   '1.0.0'],
#  'org.eclipse.viatra.addon.viewers.runtime.validation.source': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.linuxtools.valgrind.core': ['1.1.0.201910151606',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.ecp.viewmodel.feature.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.dltk.xotcl.feature.jar': ['6.0.0.201909210130', '1.0.0'],
#  'org.eclipse.mat.parser': ['1.9.1.201908260659', '1.0.0', '0.0.0'],
#  'com.ibm.icu.source': ['64.2.0.v20190507-1337', '1.0.0'],
#  'org.eclipse.emf.cdo.server.feature.jar': ['4.7.0.v20180530-1201', '1.0.0'],
#  'org.eclipse.jst.enterprise_core.feature.feature.group': ['3.15.0.v201908261515',
#   '1.0.0'],
#  'org.eclipse.wb.core.xml.feature.feature.jar': ['1.9.2.201812270937',
#   '1.0.0'],
#  'org.eclipse.ecf.filetransfer.ui.source': ['1.5.100.v20180302-2006', '1.0.0'],
#  'org.eclipse.emf.query.ocl.feature.group': ['1.12.0.201805030653', '1.0.0'],
#  'org.eclipse.tcf.te.tcf.core': ['1.6.1.201907191905', '1.0.0', '0.0.0'],
#  'org.eclipse.birt.report.engine.emitter.odt.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.papyrus.uml.decoratormodel.feature.feature.jar': ['3.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.emf.common.ui.feature.jar': ['2.17.0.v20190507-0402', '1.0.0'],
#  'org.eclipse.linuxtools.gcov.launch.source': ['1.2.0.201910151606', '1.0.0'],
#  'org.eclipse.papyrus.infra.types': ['4.0.0.201910160941', '1.0.0', '0.0.0'],
#  'org.eclipse.mat.chart': ['1.9.1.201908260659', '1.0.0', '0.0.0'],
#  'org.eclipse.acceleo.query.feature.group': ['6.0.8.201902261618', '1.0.0'],
#  'org.eclipse.jst.common.frameworks': ['1.1.701.v201903222024',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.mylyn.reviews.feature.feature.group': ['2.15.0.v20180905-0015',
#   '1.0.0'],
#  'org.eclipse.rcptt.ecl.platform': ['2.4.2.201903220647', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.validation.doc.feature.group': ['1.12.1.201812070911',
#   '1.0.0'],
#  'org.eclipse.papyrus.infra.hyperlink': ['3.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.birt.report.engine.emitter.config.ppt': ['4.7.0.v201706222054',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.cdt.testsrunner.feature.feature.group': ['9.9.0.201908121431',
#   '1.0.0'],
#  'org.eclipse.papyrus.uml.textedit.parameter.xtext': ['2.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.oomph.projectconfig.edit': ['1.5.0',
#   '1.10.0.v20180706-1242',
#   '1.0.0'],
#  'org.eclipse.jdt.apt.core': ['3.6.550.v20190919-0948', '1.0.0', '0.0.0'],
#  'org.eclipse.gef.zest.fx.ui.source.feature.jar': ['5.0.3.201910161621',
#   '1.0.0'],
#  'org.eclipse.birt.chart.device.svg.source': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.emf.eef.extended-feature.feature.group': ['1.5.1.201601141612',
#   '1.0.0'],
#  'org.eclipse.datatools.sqltools.db.generic': ['1.2.101.201811012051',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.ecp.view.categorization.feature.feature.jar': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.php.debug.core': ['7.0.0.201910101950', '1.0.0', '0.0.0'],
#  'org.eclipse.swt.cocoa.macosx.x86_64': ['3.112.100.v20191008-0601',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.wb.rcp.databinding.xwt': ['1.9.1.201812270937',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.systemtap.structures': ['4.2.0.201910151606',
#   '1.0.0',
#   '0.0.0'],
#  'org.jdom': ['1.1.1.v201101151400', '1.1.1', '1.0.0'],
#  'org.bouncycastle.bcpg': ['1.61.0.v20190602-1335', '1.61.0', '1.0.0'],
#  'org.eclipse.passage.lic.e4.ui.feature.feature.jar': ['1.0.0',
#   '0.6.0.v20190904-1720'],
#  'org.eclipse.emf.compare.uml2.rcp.ui.source': ['2.6.1.201909101346', '1.0.0'],
#  'org.eclipse.pde.ui.source': ['3.11.200.v20191003-0935', '1.0.0'],
#  'org.eclipse.rap.tools.intro.source': ['3.11.0.20190917-1349', '1.0.0'],
#  'org.eclipse.graphiti.sdk.feature.source.feature.jar': ['1.0.0',
#   '0.16.1.201909061426'],
#  'org.eclipse.birt.report.engine.odf.source': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.passage.lic.licenses.edit': ['1.0.0',
#   '0.5.0.v20190904-1720',
#   '0.0.0'],
#  'org.eclipse.cdt.make.core': ['7.4.100.201905311644', '1.0.0', '0.0.0'],
#  'org.eclipse.lsp4j.jsonrpc.debug.source': ['1.0.0', '0.8.0.v20190822-0801'],
#  'org.eclipse.gmf.runtime.emf.ui.properties.source': ['1.7.0.201905141505',
#   '1.0.0'],
#  'org.eclipse.papyrus.uml.service.types.ui': ['2.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.linuxtools.valgrind.massif': ['1.1.0.201910151606', '1.0.0'],
#  'org.eclipse.wst.server.ui': ['1.5.500.v201908161932', '1.0.0', '0.0.0'],
#  'org.eclipse.ptp': ['9.3.1.201909101427', '1.0.0'],
#  'org.eclipse.oomph.setup.targlets.feature.jar': ['1.12.0.v20190920-0437',
#   '1.0.0'],
#  'org.eclipse.launchbar.feature.jar': ['2.4.0.201907192018', '1.0.0'],
#  'org.eclipse.e4.ui.dialogs.source': ['1.1.600.v20190814-0636', '1.0.0'],
#  'org.eclipse.ocl.uml.edit': ['5.10.0.v20191014-1354', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.uml.textedit.collaborationuse.xtext.ui': ['2.1.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.ptp.linux': ['9.3.1.201909101427', '1.0.0'],
#  'org.eclipse.jst.j2ee.infopop': ['1.0.300.v201903222024', '1.0.0'],
#  'org.eclipse.m2e.wtp.sdk.feature.feature.group': ['1.4.2.20190530-0057',
#   '1.0.0'],
#  'org.eclipse.mylyn.wikitext.ui': ['3.0.33.201907111840', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.infra.types.doc': ['3.0.0.201910160941', '1.0.0'],
#  'org.eclipse.wb.swing.MigLayout.lib': ['1.9.1.201812270937',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.platform.sdk.executable.gtk.linux.ppc64le': ['4.14.0.I20191009-1800'],
#  'org.eclipse.oomph.setup.sdk.feature.jar': ['1.15.0.v20191009-0937', '1.0.0'],
# ...
#  'org.eclipse.rcptt.ecl.core.feature.group': ['2.4.2.201903220647', '1.0.0'],
#  'org.eclipse.jwt.meta': ['1.6.0.201605250940', '1.0.0', '0.0.0'],
#  'org.eclipse.mylyn.team.ui': ['3.24.2.v20180905-0014', '1.0.0', '0.0.0'],
#  'toolinggtk.linux.x86_64org.eclipse.equinox.event': ['4.14.0.I20191009-1800',
#   '1.0.0'],
#  'org.eclipse.jst.j2ee.web': ['1.1.911.v201903222025', '1.0.0', '0.0.0'],
#  'org.eclipse.emfforms.localization': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.cdt.dsf.gdb.source': ['5.7.200.201908172017', '1.0.0'],
#  'org.eclipse.emf.transaction': ['1.9.1.201805140824', '1.0.0', '0.0.0'],
#  'org.eclipse.jubula.toolkit.gef.api.source': ['5.0.0.201909100722', '1.0.0'],
#  'ch.ethz.iks.r_osgi.remote.source': ['1.2.200.v20180515-1646', '1.0.0'],
#  'org.eclipse.gef.source.feature.group': ['3.11.0.201606061308', '1.0.0'],
#  'org.eclipse.tcf.te.ui.forms': ['1.6.1.201907191905', '1.0.0', '0.0.0'],
#  'org.eclipse.xtend.ui.feature.jar': ['2.2.0.v201605260315', '1.0.0'],
#  'org.eclipse.viatra.addon.viewers.runtime.zest.feature.feature.jar': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.equinox.frameworkadmin.equinox': ['1.1.200.v20191002-0702',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.mylyn.wikitext.asciidoc': ['3.0.33.20190711143914',
#   '3.0.33',
#   '1.0.0'],
#  'org.eclipse.datatools.sqltools.sqlbuilder': ['1.2.202.201905112017',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.uml2.uml.profile.standard': ['1.5.0.v20181203-1331',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.ecp.ui': ['1.23.0.20191007-1207', '1.23.0', '1.0.0'],
#  'org.eclipse.viatra.query.runtime.rete.recipes.source': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.birt.source': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.rse.local.feature.jar': ['4.5.100.201907301734', '1.0.0'],
#  'org.eclipse.papyrus.infra.editor.welcome.nattable': ['3.0.0.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.birt.report.engine.emitter.wpml.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.birt.report.designer.ui.cubebuilder.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.xtend.util.stdlib': ['2.2.0.v201605260315', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.mapping.ui.feature.jar': ['2.13.0.v20190323-1059', '1.0.0'],
#  'org.eclipse.emfforms.swt.treemasterdetail': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.jubula.rc.rcp.ext.source': ['8.0.0.201909100722', '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.doc': ['3.9.0.v20191014-1442', '1.0.0'],
#  'org.eclipse.birt.report.designer.ui.ide': ['4.7.0.v201706222054',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.ecp.view.label.model.edit': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.xtext.ui.feature.jar': ['2.20.0.v20191014-0836', '1.0.0'],
#  'org.eclipse.emfforms.example.common.wizards': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.wst.jsdt.web.core': ['1.1.0.v201901071922', '1.0.0', '0.0.0'],
#  'org.eclipse.birt.chart.cshelp': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.ocl.doc.feature.group': ['3.14.1.v20191014-1354', '1.0.0'],
#  'org.eclipse.equinox.executable_root.gtk.linux.x86_64': ['3.8.600.v20190924-0505'],
#  'org.eclipse.eef.edit.source': ['2.1.2.201903071543', '1.0.0'],
#  'org.eclipse.graphiti.examples.tutorial': ['1.0.0',
#   '0.16.1.201909061426',
#   '0.0.0'],
#  'org.eclipse.orbit.mongodb.source': ['2.10.1.v20130422-1135', '1.0.0'],
#  'org.eclipse.jgit.archive': ['5.5.0.201909110433-r', '5.5.0', '1.0.0'],
#  'org.eclipse.dltk.xotcl.core': ['6.0.0.201909210130', '1.0.0', '0.0.0'],
#  'org.eclipse.jwt.feature.feature.group': ['1.6.0.201605250940', '1.0.0'],
#  'org.eclipse.emf.ecp.view.label.feature.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.ecf.remoteservice.rosgi.feature.source.feature.group': ['1.1.0.v20180516-2213',
#   '1.0.0'],
#  'org.eclipse.mylyn.hudson.feature.group': ['1.16.0.v20180403-2055', '1.0.0'],
#  'org.eclipse.sirius.ext.ide': ['6.2.3.201908120659', '1.0.0', '0.0.0'],
#  'org.eclipse.jubula.rc.javafx': ['8.0.0.201909100722', '1.0.0'],
#  'org.eclipse.linuxtools.profiling.launch': ['3.3.0.201910151606',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.qvtd.debug.ui': ['1.0.0', '0.21.0.v20191016-1944', '0.0.0'],
#  'org.junit.jupiter.api.source': ['5.5.1.v20190826-0900', '1.0.0'],
#  'org.eclipse.emf.ecp.emfstore.ui.search': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.apache.hadoop.zookeeper.source': ['3.3.3.v201105210832', '1.0.0'],
#  'org.eclipse.linuxtools.callgraph.docs': ['1.0.0.201910151606', '1.0.0'],
#  'org.eclipse.rcptt.watson.feature.jar': ['2.4.2.201903220647', '1.0.0'],
#  'org.eclipse.e4.ui.workbench.swt.source': ['1.0.0',
#   '0.14.800.v20190930-1643'],
#  'org.eclipse.gef.zest.fx.ui.feature.group': ['5.0.3.201910161621', '1.0.0'],
#  'org.eclipse.datatools.connectivity.oda.template.ui': ['3.4.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.gef.feature.group': ['3.11.0.201606061308', '1.0.0'],
#  'org.eclipse.emfforms.swt.treemasterdetail.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.viatra.query.patternlanguage.emf.source': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.apache.commons.io': ['2.6.0.v20190123-2029', '2.6.0', '1.0.0'],
#  'org.eclipse.ptp.etfw.tau.papiselect': ['4.0.0.201909101427',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jdt.junit4.runtime': ['1.1.1100.v20191009-0503',
#   '1.0.0',
#   '0.0.0'],
#  'org.apache.ant.source': ['1.10.7.v20190926-0324', '1.0.0'],
#  'org.eclipse.tcf.te.ui.controls': ['1.6.1.201907191951', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.converter.source.feature.jar': ['2.15.0.v20190418-1022',
#   '1.0.0'],
#  'org.apache.batik.bridge.source': ['1.6.0.v201011041432', '1.0.0'],
#  'org.eclipse.papyrus.uml.architecture': ['1.1.300.201910160941',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.equinox.p2.transport.ecf.source': ['1.2.300.v20191001-0955',
#   '1.0.0'],
#  'org.eclipse.tm4e.feature.feature.jar': ['1.0.0', '0.3.4.201909051118'],
#  'org.eclipse.gef.mvc.fx.feature.group': ['5.2.0.201910161621', '1.0.0'],
#  'org.eclipse.emf.ecore.source.feature.group': ['2.20.0.v20190920-0401',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.view.template.model.edit.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.birt.osgi.runtime.source.feature.group': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.qvtd.examples.source.feature.group': ['1.0.0',
#   '0.21.0.v20191016-1944'],
#  'org.eclipse.mylyn.discovery.core.source': ['3.24.2.v20180904-2231', '1.0.0'],
#  'org.eclipse.emf.ecp.view.label.ui.swt.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.gef.fx.jface.feature.jar': ['5.0.2.201910161621', '1.0.0'],
#  'org.eclipse.mylyn.commons.sdk.feature.group': ['3.24.2.v20180904-2231',
#   '1.0.0'],
#  'org.eclipse.gef.layout.feature.jar': ['5.0.0.201910161621', '1.0.0'],
#  'org.apache.bcel': ['5.2.0.v201005080400', '5.2.0', '1.0.0'],
#  'org.eclipse.wst.jsdt.chromium.debug.js': ['1.0.0', '0.1.200.v201903222101'],
#  'org.eclipse.oomph.base': ['1.12.0.v20190705-1018', '1.12.0', '1.0.0'],
#  'org.eclipse.birt.feature.jar': ['4.7.0.v201706222054', '1.0.0'],
#  'org.sonatype.m2e.mavenarchiver.feature.feature.group': ['1.0.0',
#   '0.17.4.201905300046'],
#  'org.eclipse.ecf.provider.generic.remoteservice.feature.feature.jar': ['1.1.100.v20180516-2213',
#   '1.0.0'],
#  'org.eclipse.datatools.connectivity.oda.consumer': ['3.4.101.201811012051',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.compare.uml2.feature.jar': ['3.3.8.201909101346', '1.0.0'],
#  'org.eclipse.emf.ecp.view.vertical.model.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.equinox.server.p2.feature.group': ['1.9.100.v20191008-0645',
#   '1.0.0'],
#  'org.eclipse.swtbot.generator': ['2.8.0.201906121535', '1.0.0', '0.0.0'],
#  'org.eclipse.rcptt.ecl.debug.core': ['2.4.2.201905060849', '1.0.0', '0.0.0'],
#  'org.eclipse.cdt.debug.application': ['1.1.300.201908121111',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.mylyn.tasks.ui.source': ['3.24.2.v20180905-0003', '1.0.0'],
#  'org.eclipse.papyrus.infra.ui.emf': ['2.2.0.201910160941', '1.0.0', '0.0.0'],
#  'org.eclipse.papyrus.infra.ui.feature.feature.jar': ['3.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.jubula.communication.source': ['4.0.0.201909100722', '1.0.0'],
#  'org.eclipse.cdt.make.core.source': ['7.4.100.201905311644', '1.0.0'],
#  'org.eclipse.ecf.discovery.ui.model.source': ['3.0.100.v20180302-1807',
#   '1.0.0'],
#  'org.eclipse.equinox.cm.source': ['1.4.200.v20191001-1333', '1.0.0'],
#  'org.eclipse.ui.workbench': ['3.117.0.v20191006-0926', '1.0.0', '0.0.0'],
#  'org.eclipse.gmf.runtime.emf.type.core': ['1.9.0.201905141505',
#   '1.0.0',
#   '0.0.0'],
#  'org.glassfish.jersey.media.jersey-media-json-jackson': ['2.22.1.v20161117-2005',
#   '2.22.1',
#   '1.0.0'],
#  'org.eclipse.birt.report.designer.ui.lib.explorer.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.jubula.app.autagent': ['8.0.0.201909100722', '1.0.0'],
#  'org.eclipse.remote.feature.group': ['3.0.1.201909031456', '1.0.0'],
#  'org.eclipse.ecf.remoteservices.tooling.pde.source': ['1.0.100.v20180302-2006',
#   '1.0.0'],
#  'org.eclipse.zest.feature.jar': ['1.7.0.201606061308', '1.0.0'],
#  'org.eclipse.tm.terminal.view.ui': ['4.5.102.201907301733', '1.0.0', '0.0.0'],
#  'org.eclipse.datatools.sqldevtools.schemaobjecteditor.feature.feature.group': ['1.14.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.platform.sdk': ['4.14.0.I20191009-1800'],
#  'org.eclipse.linuxtools.callgraph.core.source': ['3.1.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.team.core.source': ['3.8.800.v20190925-1852', '1.0.0'],
#  'org.eclipse.birt.report.engine.emitter.config.wpml.source': ['4.7.0.v201706222054',
#   '1.0.0'],
#  'org.eclipse.birt.cshelp': ['4.7.0.v201706222054', '1.0.0'],
#  'org.eclipse.egf.model.ui.feature.feature.group': ['1.6.1.201910041425',
#   '1.0.0'],
#  'org.eclipse.mylyn.ide_feature.feature.group': ['3.24.2.v20180905-0014',
#   '1.0.0'],
#  'org.eclipse.egf.producer.ui.feature.feature.jar': ['1.6.1.201910041425',
#   '1.0.0'],
#  'org.eclipse.emf.cdo.transfer.workspace.source': ['4.2.400.v20180529-1130',
#   '1.0.0'],
#  'org.eclipse.cdt.msw.feature.jar': ['9.9.0.201909091956', '1.0.0'],
#  'org.eclipse.libra.framework.editor.ui': ['1.0.0',
#   '0.3.1.201609011955',
#   '0.1.0'],
#  'org.eclipse.papyrus.infra.core.feature.feature.group': ['3.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.equinox.executable.feature.jar': ['3.8.600.v20190924-0505',
#   '1.0.0'],
#  'org.eclipse.mylyn.bugzilla.ui.source': ['3.24.2.v20180905-0003', '1.0.0'],
#  'org.apache.batik.util.source': ['1.6.0.v201011041432', '1.0.0'],
#  'org.eclipse.emfforms.view.multisegment.model.edit.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.mylyn.wikitext.markdown.ui.source': ['3.0.33.201907111840',
#   '1.0.0'],
#  'org.eclipse.gmf.examples.runtime.diagram.logic.model.edit': ['1.2.0.201905141505',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.ocl.ui': ['1.8.400.v20191014-1354', '1.0.0', '0.0.0'],
#  'org.eclipse.datatools.sqltools.doc.user.contexts': ['1.7.101.201811012051',
#   '1.0.0'],
#  'org.eclipse.tm4e.ui': ['1.0.0', '0.3.4.201909051021', '0.0.0'],
#  'org.eclipse.linuxtools.profiling.feature.group': ['7.5.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.jetty.continuation': ['9.4.21.v20190926', '9.4.21', '1.0.0'],
#  'org.eclipse.mylyn.wikitext.textile': ['3.0.33.20190711143914',
#   '3.0.33',
#   '1.0.0'],
#  'org.eclipse.jgit.lfs.server': ['5.5.0.201909110433-r', '5.5.0', '1.0.0'],
#  'org.eclipse.ant.launching.source': ['1.2.700.v20190925-0438', '1.0.0'],
#  'org.eclipse.wst.jsdt.doc': ['2.0.200.v201903222101', '1.0.0'],
#  'org.eclipse.emf.ecp.emfforms.sdk.feature.feature.group': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.xtext.xtext.ui.examples': ['2.20.0.v20191014-0620',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.m2m.atl.core.source': ['4.1.0.v201909021645', '1.0.0'],
#  'toolingorg.eclipse.platform.ide.config.gtk.linux.x86_64': ['4.14.0.I20191009-1800'],
#  'org.eclipse.emf.compare.source': ['3.5.3.201909101346', '1.0.0'],
#  'org.eclipse.cdt.debug.gdbjtag.core': ['9.3.0.201908231443',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.e4.ui.workbench.source': ['1.11.0.v20190930-1643', '1.0.0'],
#  'org.eclipse.viatra.query.runtime.feature.source.feature.group': ['2.3.0.201910160845',
#   '1.0.0'],
#  'org.eclipse.oomph.setup.workbench.feature.jar': ['1.12.0.v20190929-1544',
#   '1.0.0'],
#  'org.eclipse.emf.compare.diagram.ide.ui.sirius': ['1.1.1.201909101346',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.gef.layout.doc': ['5.0.0.201910161621', '1.0.0'],
#  'org.eclipse.passage.lic.equinox.feature.feature.jar': ['1.0.0',
#   '0.6.0.v20190904-1720'],
#  'org.eclipse.linuxtools.profiling.ui.capability.source': ['1.0.0.201910151606',
#   '1.0.0'],
#  'org.eclipse.rcptt.tesla.recording.core.ecl': ['2.4.2.201903220647',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.xsd.sdk.feature.group': ['2.19.0.v20190918-1629', '1.0.0'],
#  'org.eclipse.remote.jsch.core': ['1.0.0.201909031456', '1.0.0', '0.0.0'],
#  'org.eclipse.tracecompass.gdbtrace.core': ['1.0.3.201909110900',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.importer.rose.source': ['2.10.0.v20180706-1146', '1.0.0'],
#  'org.eclipse.emf.converter.source': ['2.10.0.v20180706-1146', '1.0.0'],
#  'org.eclipse.emf.validation.source': ['1.8.0.201812070911', '1.0.0'],
#  'org.eclipse.equinox.supplement.source': ['1.9.100.v20190911-0531', '1.0.0'],
#  'org.eclipse.sirius.runtime.ide.xtext.feature.group': ['6.2.3.201908120659',
#   '1.0.0'],
#  'org.eclipse.egf.console': ['1.6.1.201910041425', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.ecp.application.e4.source': ['1.23.0.20191007-1207',
#   '1.0.0'],
#  'org.eclipse.emfforms.swt.core.plugin': ['1.23.0.20191007-1207',
#   '1.23.0',
#   '1.0.0'],
#  'org.eclipse.tracecompass.analysis.lami.core': ['1.1.1.201909110900',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.mylyn.commons.repositories.http.feature.group': ['1.16.0.v20180904-2231',
#   '1.0.0'],
#  'org.eclipse.jst.ws.axis2.core': ['1.0.300.v201903050508', '1.0.0', '0.0.0'],
#  'org.eclipse.ui.views.properties.tabbed': ['3.8.700.v20191002-1102',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.xtext': ['2.20.0.v20191014-0526', '1.0.0', '0.0.0'],
#  'org.eclipse.datatools.enablement.ingres': ['1.2.101.201811012051',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.importer.java': ['2.11.0.v20190418-1022', '1.0.0', '0.0.0'],
#  'org.eclipse.egf.portfolio.genchain.editor': ['1.6.1.201910041425',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jgit.http.apache.feature.group': ['5.5.0.201909110433-r',
#   '1.0.0'],
#  'org.eclipse.equinox.cm': ['1.6.0',
#   '1.4.200.v20191001-1333',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.emf.cdo.edit.source': ['4.4.200.v20180529-1130', '1.0.0'],
#  'org.eclipse.papyrus.uml.decoratormodel.feature.feature.group': ['3.0.0.201910160941',
#   '1.0.0'],
#  'org.eclipse.equinox.bidi': ['1.2.200.v20191008-0718', '1.0.0', '0.0.0'],
#  'org.eclipse.jubula.autagent.common': ['8.0.0.201909100722',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.jgit.ui.source': ['5.5.0.201909110433-r', '1.0.0'],
#  'org.eclipse.emf.source.feature.group': ['2.20.0.v20190920-0412', '1.0.0'],
#  'org.eclipse.wb.swing.doc.user.feature.feature.group': ['1.9.2.201812270937',
#   '1.0.0'],
#  'org.eclipse.tm4e.feature.feature.group': ['1.0.0', '0.3.4.201909051118'],
#  'org.eclipse.viatra.query.tooling.generator.model.ui': ['2.3.0.201910160845',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.sirius.runtime.ide.xtext.feature.jar': ['6.2.3.201908120659',
#   '1.0.0'],
#  'org.eclipse.xtend.source': ['2.2.0.v201605260315', '1.0.0'],
#  'org.eclipse.wst.jsdt.debug.core': ['3.2.200.v201903222047',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.rse.subsystems.shells.ssh': ['4.5.100.201901312252',
#   '1.0.0',
#   '0.0.0'],
#  'org.eclipse.cdt.autotools.docs': ['2.0.200.201909091953', '1.0.0'],
#  'org.eclipse.m2m.qvt.oml.tools.coverage.junit': ['1.5.2.v20191014-1442',
#   '1.0.0',
#   '0.0.0'],
#  'org.apache.commons.codec.source': ['1.10.0.v20180409-1845', '1.0.0'],
#  'org.eclipse.bpel.model': ['1.1.2.Final-v20180621-1835', '1.0.0', '0.0.0'],
#  'org.eclipse.emf.cdo.server.db.feature.group': ['4.6.0.v20180529-1130',
#   '1.0.0'],
#  'org.eclipse.emf.ecp.edit.source': ['1.23.0.20191007-1207', '1.0.0'],
#  'org.eclipse.cdt.debug.standalone.feature.jar': ['9.9.0.201909091956',
#   '1.0.0'],
#  'org.eclipse.passage.lic.net': ['1.0.0', '0.5.0.v20190904-1720', '0.0.0'],
#  ...}
